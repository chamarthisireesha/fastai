# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *

# %%
path = untar_data(URLs.BIWI_HEAD_POSE)

# %% [markdown]
# Standard procedure to access this data

# %%
cal = np.genfromtxt(path/'01'/'rgb.cal', skip_footer=6); cal
# Out:
# array([[517.679,   0.   , 320.   ],
#        [  0.   , 517.679, 240.5  ],
#        [  0.   ,   0.   ,   1.   ]])

# %%
fname = '09/frame_00667_rgb.jpg'

# %%
def img2txt_name(f): return path/f'{str(f)[:-7]}pose.txt'

# %%
img = open_image(path/fname)
img.show()

# %%
ctr = np.genfromtxt(img2txt_name(fname), skip_header=3); ctr
# Out:
# array([187.332 ,  40.3892, 893.135 ])

# %%
def convert_biwi(coords):
    c1 = coords[0] * cal[0][0]/coords[2] + cal[0][2]
    c2 = coords[1] * cal[1][1]/coords[2] + cal[1][2]
    return tensor([c2,c1])

def get_ctr(f):
    ctr = np.genfromtxt(img2txt_name(f), skip_header=3)
    return convert_biwi(ctr)

def get_ip(img,pts): return ImagePoints(FlowField(img.size, pts), scale=True)

# %%
get_ctr(fname)
# Out:
# tensor([263.9104, 428.5814])

# %%
ctr = get_ctr(fname)
img.show(y=get_ip(img, ctr), figsize=(6, 6))

# %% [markdown]
# Finding the center of the face and display it by a dot -- coordinates given by get_ctr(fname)

# %% [markdown]
# This is not a classification model -- no lables
#
# The output is continous numbers -- this is a regression problem

# %% [markdown]
# ## Dataset
#
# label based on the function generated get_ctr
#
# Validation set we picked one folder as a validation set
#
# Similar to the previous examples, tfm_y = True because as we transform the image, the red dot corresponding cordinate should move

# %%
data = (PointsItemList.from_folder(path)
        .split_by_valid_func(lambda o: o.parent.name=='13')
        .label_from_func(get_ctr)
        .transform(get_transforms(), tfm_y=True, size=(120,160))
        .databunch().normalize(imagenet_stats)
       )

# %%
data.show_batch(3, figsize=(9,6))

# %%
learn = cnn_learner(data, models.resnet34)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
# ...

# %%
lr = 2e-2

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.121915</td>
#       <td>0.008665</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.044022</td>
#       <td>0.003393</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.014386</td>
#       <td>0.001441</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.008194</td>
#       <td>0.002645</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.006586</td>
#       <td>0.002796</td>
#       <td>01:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# Check for dataaugmentation for the tutorials
